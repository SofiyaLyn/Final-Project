# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/sonetalyn/Desktop/Asia/work.csv')
print(df)
# Out:
#          country countrycode  year  month      cpi_sa  cpi_yoy_nsa  \
# 0       Malaysia         MYS  1998      2   76.090230     4.415547
# 1    Philippines         PHL  1998      2   53.158154     7.651601
# 2       Thailand         THA  1998      2   75.109905     8.775797
# 3      Singapore         SGP  1998      2   86.310768     1.047782
# 4       Malaysia         MYS  1998      3   76.823327     5.200332
# ..           ...         ...   ...    ...         ...          ...
# 967     Thailand         THA  2018      3  112.939273     0.800317
# 968     Thailand         THA  2018      4  113.056494     1.086030
# 969  Philippines         PHL  2018      4  129.982280     4.508566
# 970     Malaysia         MYS  2018      4  121.635243     1.427283
# 971    Singapore         SGP  2018      4  115.989924     0.072107
#
#      exchange_rate_neer  exchange_rate_reer  exchnage_rate_vs_usd  \
# 0             98.532484           95.946542              3.826650
# ...

# %%
countries = 'Malaysia Philippines Thailand Singapore'.split()

# %%
import csv

# %%
filename = '/Users/sonetalyn/Desktop/Asia/work.csv'

with open(filename, 'r') as csvfile:
    datareader = csv.reader(csvfile)
    for row in datareader:
        print(row)
# Out:
# ['country', 'countrycode', 'year', 'month', 'cpi_sa', 'cpi_yoy_nsa', 'exchange_rate_neer', 'exchange_rate_reer', 'exchnage_rate_vs_usd', 'ind_prod_const', 'ind_prod_const_sa', 'time', 'usa_imp_sa', 'usa_ip_sa', 'chn_ip_sa', 'ln_ip', 'ln_usa_ip', 'ln_chn_ip', 'ln_usa_imports', 'ln_er_usd', 'cc']
# ['Malaysia', 'MYS', '1998', '2', '76.09022996', '4.415547471', '98.5324845', '95.94654225', '3.82665', '4526050472', '4769492746', '457', '74184', '2.33295E+11', '50452115592', '22.28550579', '26.1755713', '24.64429052', '11.21430377', '1.341989747', 'MYS']
# ['Philippines', 'PHL', '1998', '2', '53.15815445', '7.651601181', '132.8964406', '93.1444605', '40.14125', '6599709764', '6233136329', '457', '74184', '2.33295E+11', '50452115592', '22.55314547', '26.1755713', '24.64429052', '11.21430377', '3.692404484', 'PHL']
# ...

# %%
df = pd.read_csv(filename)

for index, row in df.iterrows():
    print(row)
# Out:
# country                       Malaysia
# countrycode                        MYS
# year                              1998
# month                                2
# cpi_sa                        76.09023
# cpi_yoy_nsa                   4.415547
# exchange_rate_neer           98.532484
# exchange_rate_reer           95.946542
# exchnage_rate_vs_usd           3.82665
# ind_prod_const              4526050472
# ind_prod_const_sa           4769492746
# time                               457
# usa_imp_sa                     74184.0
# usa_ip_sa               233295000000.0
# chn_ip_sa                50452115592.0
# ln_ip                        22.285506
# ln_usa_ip                    26.175571
# ln_chn_ip                    24.644291
# ln_usa_imports               11.214304
# ln_er_usd                      1.34199
# cc                                 MYS
# Name: 0, dtype: object
# country                    Philippines
# countrycode                        PHL
# ...

# %%
country_dictionary = {}

for country in df.country:
    first_letter = country[0].upper()
    if first_letter in country_dictionary:
        country_dictionary[first_letter].append(country)
    else:
        country_dictionary[first_letter] = [country]
    
print(country_dictionary)

df.describe()
# Out:
# {'M': ['Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malaysia', 'Malays
# ...

# %%
sns.regplot (x='year', y='exchnage_rate_vs_usd', data=df)
plt.show()

# %%
# Out:
#   File "/var/folders/h1/_vx7lz596z5c_kynzkqz8l180000gn/T/ipykernel_67006/339777499.py", line 1
#     git status
#         ^
# SyntaxError: invalid syntax
